# %%
# Importing the Libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('bmh')

# %%
# Load the data

df= pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# From the above , we observe that there are so many features have missing values ,such as Alley, PoolQC.
# As we have so many features to analyse , it may be better to focus on the ones which can gives the real insights.
# Let's remove 'Id' and the features with 30% or less NaN values.

# %%
 #df.count()
 #df.count() does not include NaN values.
df2= df[[column for column in df if df[column].count()/len(df) >=0.3]]
#del df['Id'] 
print('List of dropped Columns :', end=' ')
for c in df.columns:
    if c not in df2.columns:
        print(c, end=', ')
print('\n')

df = df2
#df.info()
# Out:
# List of dropped Columns :

# %% [markdown]
# Now lets look at how the housing price is distributed.

# %%
print(df['SalePrice'].describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(9, 8))
sns.distplot(df['SalePrice'], color='g', bins=100, hist_kws={'alpha': 0.5});

# %% [markdown]
# Observations :
#     1. Prices are skewed right
#     2. Some outliers lies above ~500,000
# We will have to evetually get rid of out liers to get the normal distribution of the independent varialble [SalePrice].

# %% [markdown]
# # Numerical Data Distribution

# %% [markdown]
# Lets look at the distribution of all the features by ploting them.
#
# To do so, lets first list all the types of our data from our dataset and take only the numerical value columns.

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('int64'), dtype('float64')]

# %%
df_num= df.select_dtypes(include=['float64', 'int64'])
print(df_num.columns)
df_num.head()
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# ...

# %% [markdown]
# Now lets plot them all.

# %%
df_num.hist(figsize=(16,30) , bins=50, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# Features such as '1stFlrSF','TotalBsmtSF','LotFrontage','GrLiveArea'seems to share similar distribution to the one we
# have with 'SalePrice' . Still lot to look for anymore clues....

# %% [markdown]
# # Correlation:

# %% [markdown]
# We will try to find which features are strongly correlated wiht 'SalePrice'.
# We store them in a var called golden_feature_list.

# %%
df_num_corr= df_num.corr()['SalePrice'][:-1]
golden_feature_list= df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending= False)
print('There is {} strongly correlated values with SalePrice: \n{}'.format(len(golden_feature_list), golden_feature_list))
# Out:
# There is 10 strongly correlated values with SalePrice:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %% [markdown]
# Now we have a strongly correlated values but this list is incomplete as we know that correlation is affected by outliers.
# So we could follow as follow:
#
#     - Plot the numerical features and see which ones have very few or explainable outliers.
#     - Remove the outliers from these features and see which one can have a good correlation wihtout thier outlier.
#
# Btw,Correlation by iteslf does not always explain the relationship between data , so ploting them could even lead us
# to new insights and in the same manner, check that our correlated values have linear relationship to the 'SalePrice'.
#
# For Example, relationship such as curvilinear relationship can not be guessed just by looking at the correlation value ,
# so lets take the features that we excluded from our correlation table and plot them to see if they show some kind of pattern.

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars= df_num.columns[i:i+5],
                y_vars=['SalePrice'])

# %% [markdown]
# We can clearly identify some relationship.Most of them seems to have a linear relationship with the 'SalePrice' and
# if we look closely at the data we can see that a lot of data points are located on x=0 which may indicate tha
# absence of such featre in the house.
#
# Example : 'OpenPorchSF' , 'EnclosedPorch' indicates most of the houses do not have them.

# %% [markdown]
# So lets remove these 0 values and repeat the process of finding correlated values:

# %%
import operator


individual_feature_df=[]

for i in range(0, len(df_num.columns)-1): # removing the last columns 'SalePrice'
    tmpDf = df_num[[df_num.columns[i], 'SalePrice']]
    tmpDf = tmpDf[tmpDf[df_num.columns[i]] !=0]
    individual_feature_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['SalePrice'][0]  for feature in individual_feature_df}

all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))

for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key,value))
# Out:
#    KitchenAbvGr: -0.13920069217785566
#        HalfBath: -0.08439171127179887
#      MSSubClass: -0.08428413512659523
#     OverallCond: -0.0778558940486776
#          YrSold: -0.028922585168730426
#    BsmtHalfBath: -0.028834567185481712
#        PoolArea: -0.014091521506356928
#    BsmtFullBath: 0.011439163340408634
#          MoSold: 0.04643224522381936
#       3SsnPorch: 0.06393243256889079
#     OpenPorchSF: 0.08645298857147708
#         MiscVal: 0.08896338917298924
#      Fireplaces: 0.1216605842136395
#       BsmtUnfSF: 0.16926100049514192
#    BedroomAbvGr: 0.18093669310849045
#      WoodDeckSF: 0.19370601237520677
#      BsmtFinSF2: 0.19895609430836586
#   EnclosedPorch: 0.2412788363011751
#     ScreenPorch: 0.25543007954878405
#         LotArea: 0.2638433538714063
#    LowQualFinSF: 0.3000750165550133
#     LotFrontage: 0.35179909657067854
#      MasVnrArea: 0.4340902197568926
#      BsmtFinSF1: 0.4716904265235731
#     GarageYrBlt: 0.48636167748786213
# ...

# %% [markdown]
# Interestingly we found another strongly correlated value by cleaning up the data a bit.
# Now our golden_feature_list var look like this.

# %%
golden_feature_list= [key for key, value in all_correlations if abs(value) >=0.5]

print('There are {} strongly correlated values with SlarePrice:\n {}'.format(len(golden_feature_list),
                                                                             golden_feature_list))
# Out:
# There are 11 strongly correlated values with SlarePrice:
#  ['YearRemodAdd', 'YearBuilt', 'TotRmsAbvGrd', 'FullBath', '1stFlrSF', 'GarageArea', 'TotalBsmtSF', 'GarageCars', '2ndFlrSF', 'GrLivArea', 'OverallQual']

# %% [markdown]
# We found very strongly correlated predictors with 'SalePrice'. Later with feature engineering we may add
# dummy values where values of given feature is > 0 would be 1 and '=0' would be 0.
#
# CONCLUSION
#
#
# By looking at correlation between numerical values we discovered 11 features which have a strong relationship
# to a house price.Besides correlation we did not find any notable pattern on the dates which not correlated.

# %% [markdown]
# # Feature to Feature Relationship

# %% [markdown]
# Trying to plot all he numerical features in a seborn pairplot will take us too much time and will be hard to interpret.
# We can try to see if some variables are linked between each other and then explain their relation with common sense.

# %%
# Correlation each feature with all other features.  
print('------------')
corr = df_num.drop('SalePrice', axis=1).corr()
#print(corr)
plt.figure(figsize=(12,10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)],
           cmap='viridis',
           vmax=1.0,
           vmin=-1.0,
           linewidths=0.1,
           annot= True,
           annot_kws={'size': 8},
           square=True)
# Out:
# ------------

# %% [markdown]
# A lot of features seems to be correlated between each other but some of them such as YearBuild/GarageYrBlt may just
# indicate a price inflation over the years.
# As for 1stFlrSF/TotalBsmtSF, it is normal that the more the 1st floor is large , the more the total the basement will be large.

# %% [markdown]
# Now for the ones which are less obvious we can see that :
#
#     . There is a strong negetive correlation between BsmtUnfSF(Unfirnished sqaurer feet of basement area) and
#     . HalfBath/2ndFlrSF is interesting and may indicate that people give an importance having half bathroom in the 2nd Floor.
#
#     More & More ....

# %% [markdown]
# # Q -> Q (Quantitative to Quantitative Relationship)

# %% [markdown]
# Let's now examin the quantitative features of our dataframe and how they relate to the 'SalePrice' which
# is also quantitative.
#
#
# Some of the features of our dataset are categorical. To seperate the categorical from quantative fetures
# As per the file , the following columns are referred as quantitative features.

# %%
quantitative_features_list = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'TotalBsmtSF', '1stFlrSF',
    '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
    'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 
    'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice']
df_quantitative_values= df[quantitative_features_list]
df_quantitative_values.head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  TotalBsmtSF  \
# 0         65.0     8450       196.0         706           0          856
# 1         80.0     9600         0.0         978           0         1262
# 2         68.0    11250       162.0         486           0          920
# 3         60.0     9550         0.0         216           0          756
# 4         84.0    14260       350.0         655           0         1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  ...  GarageCars  GarageArea  \
# 0       856       854             0       1710  ...           2         548
# 1      1262         0             0       1262  ...           2         460
# 2       920       866             0       1786  ...           2         608
# 3       961       756             0       1717  ...           3         642
# 4      1145      1053             0       2198  ...           3         836
#
# ...

# %% [markdown]
# Still we have a lot of features to analyse here. Take a strongly correlated quantitative features from this
# dataset and analyse them one by one.

# %%
features_to_analysis= [x for x in quantitative_features_list if x in golden_feature_list]
features_to_analysis.append('SalePrice')
features_to_analysis
# Out:
# ['TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'SalePrice']

# %% [markdown]
# Let's look at thier distribution.

# %%
fig, ax = plt.subplots(round(len(features_to_analysis) / 3), 3 , figsize= (18, 12))

for i, ax in enumerate(fig.axes):
    if i < len(features_to_analysis) -1:
        sns.regplot(x=features_to_analysis[i], y = 'SalePrice' , data=df[features_to_analysis], ax=ax)

# %% [markdown]
# We can see that features such as TotalBsmtSF ,1stFltSF ,GrLivArea have a big spread .

# %% [markdown]
# # C -> Q (Categrocal to Quantitative Relationship)

# %% [markdown]
# Lets get all the categorical features of our dataset and see if we can find some insight in them.
# Lets remove quantitative_features_list from our entire dataframe.

# %%
categorail_features = [a for a in quantitative_features_list[: -1] + df.columns.tolist() 
                       if (a not in quantitative_features_list[:-1]) 
                       or (a not in df.columns.tolist())]
df_categ=df[categorail_features]
df_categ.head()
print(df_categ.columns)
# Out:
# Index(['MSSubClass', 'MSZoning', 'Street', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'BsmtUnfSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'MoSold',
#        'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# And the Non-Numerical Features

# %%
df_not_num= df_categ.select_dtypes(include=['O'])
print('There is {} non numerical features including :\n{}'.format(len(df_not_num.columns),df_not_num.columns.tolist()))
# Out:
# There is 39 non numerical features including :
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %% [markdown]
# Now lets plot some of them

# %%
plt.figure(figsize=(10,6))
ax= sns.boxplot(x='BsmtExposure', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor='k')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %%
plt.figure(figsize=(10,6))
ax= sns.boxplot(x='SaleCondition', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor='k')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# Finally let look at thier distribution.

# %%
fig, axes = plt.subplots(round(len(df_not_num.columns) / 3), 3 , figsize = (12,30))

for i, ax in enumerate(fig.axes):
    if i < len(df_not_num.columns):
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(),
                          rotation=45)
        sns.countplot(x=df_not_num.columns[i],
                     alpha=0.7,
                     data=df_not_num,
                     ax=ax)
fig.tight_layout()

# %% [markdown]
# We can see that some categories are predominant for some features such as 'Utilities', 'Heating', 'GarageCond',
# 'Funcational' .. These features may not be relevent for our predective model.
